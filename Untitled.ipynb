# %%
import pandas as pd, numpy as np
from sklearn.model_selection import train_test_split as tts
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# <h3>
# 1Q<br>
# a. Write a Python program to predict house prices using Simple Linear Regression on a given dataset.<br>
# b. Predict the salary of an employee based on their years of experience using Simple
# Linear Regression with train and test data.</h3>

# %%
dfq1 = pd.read_csv("homeprices.csv")
dfq1.head()
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
from sklearn.linear_model import LinearRegression as LR, LogisticRegression as Lor
x_train_1a, x_test_1a, y_train_1a, y_test_1a = tts(dfq1.iloc[:, 0:-1], dfq1.iloc[:, -1], test_size=0.2, random_state=42)
model = LR().fit(x_train_1a, y_train_1a)
y_pred = model.predict(x_test_1a)

# %%
model.predict(x_test_1a).round(2)
# Out:
# array([721538.46])

# %%
df1q2 = pd.read_csv("Salary_Data.csv")
df1q2.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
x_train_1b, x_test_1b, y_train_1b, y_test_1b = tts(df1q2.iloc[:, 0:-1], df1q2.iloc[:, -1], test_size=0.2)
model2 = LR().fit(x_train_1b, y_train_1b)
y_pred2 = model2.predict(x_test_1b)

# %%
for i, j in enumerate(y_pred2):
    print(f"Est Salary for {x_test_1b.values[i][0]} years is : {j.round(2)}")
# Out:
# Est Salary for 3.7 years is : 60001.99
# Est Salary for 5.3 years is : 75333.46
# Est Salary for 3.0 years is : 53294.48
# Est Salary for 7.9 years is : 100247.09
# Est Salary for 1.1 years is : 35088.36
# Est Salary for 10.3 years is : 123244.29

# %% [markdown]
# <h3>Q2.<br> a. Apply Logistic Regression to predict whether a person will take insurance or not based
# on their age for a given dataset.<br>
# b. Use a Decision Tree Classifier model to decide whether to play cricket or not under
# given weather conditions.
# </h3>

# %%
df2q1 = pd.read_csv("insurance_data.csv")
df2q1.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
x_train_2a, x_test_2a, y_train_2a, y_test_2a = tts(df2q1.iloc[:, 0:-1], df2q1.iloc[:, -1], test_size=0.2, random_state=42)
model3 = Lor().fit(x_train_2a, y_train_2a)

# %%
y_pred3 = model3.predict(x_test_2a)

# %%
for i, j in enumerate(y_pred3):
    print(f"Person of age {x_test_2a.values[i][0]} years is  will {'buy' if j==1 else 'not buy'} insurance")
# Out:
# Person of age 62 years is  will buy insurance
# Person of age 29 years is  will not buy insurance
# Person of age 61 years is  will buy insurance
# Person of age 26 years is  will not buy insurance
# Person of age 22 years is  will not buy insurance
# Person of age 28 years is  will not buy insurance

# %%
df2q2 = pd.read_csv("PlayCricket.csv")
df2q2.head()
# Out:
#     outlook  temp humidity  windy play
# 0     sunny   hot     high  False   no
# 1     sunny   hot     high   True   no
# 2  overcast   hot     high  False  yes
# 3     rainy  mild     high  False  yes
# 4     rainy  cool   normal  False  yes

# %%
df2q2 = pd.get_dummies(df2q2, columns=df2q2.columns[:-1], drop_first=False)
df2q2.head()
# Out:
#   play  outlook_overcast  outlook_rainy  outlook_sunny  temp_cool  temp_hot  \
# 0   no             False          False           True      False      True
# 1   no             False          False           True      False      True
# 2  yes              True          False          False      False      True
# 3  yes             False           True          False      False     False
# 4  yes             False           True          False       True     False
#
#    temp_mild  humidity_high  humidity_normal  windy_False  windy_True
# 0      False           True            False         True       False
# 1      False           True            False        False        True
# 2      False           True            False         True       False
# 3       True           True            False         True       False
# 4      False          False             True         True       False

# %%
df2q2 = df2q2.replace({
    'no':0,
    'yes':1,
    False:0,
    True:1
})
# Out:
# C:\Users\Sainath\AppData\Local\Temp\ipykernel_19996\3390516332.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df2q2 = df2q2.replace({

# %%
x_train_2b, x_test_2b, y_train_2b, y_test_2b = tts(df2q2.iloc[:, 1:], df2q2.iloc[:, 0], test_size=0.2, random_state=42)
from sklearn.tree import DecisionTreeClassifier as DTC

# %%
model4 = DTC(criterion='gini', random_state=42)
model4.fit(x_train_2b, y_train_2b)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred4 = model4.predict(x_test_2b)
accuracy_score(y_test_2b, y_pred4)
# Out:
# 1.0

# %% [markdown]
# <h3>Q3<br> a. Perform Exploratory Data Analysis (EDA) on any dataset of your choice and
# summarize its key insights.<br>
# b. Predict home prices using Multiple Linear Regression for a given dataset.</h2>

# %%
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['species'] = iris.target
df['species'] = df['species'].map({0: 'setosa', 1: 'versicolor', 2: 'virginica'})
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   species            150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
# Plot feature distributions
fig, axs = plt.subplots(2, 2, figsize=(10, 7))
col_index = 0
for row in range(2):
    for col in range(2):
        axs[row, col].hist(df[df.columns[col_index]])
        axs[row, col].set_xlabel(f"{df.columns[col_index]}")
        col_index += 1
plt.tight_layout()
plt.show()

# %%
df3q2 = pd.read_csv("Housing.csv")
df3q2.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df3q2 = df3q2.replace({
    'no':0,'yes':1,
})
# Out:
# C:\Users\Sainath\AppData\Local\Temp\ipykernel_19996\1943785141.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df3q2 = df3q2.replace({

# %%
df3q2 = pd.get_dummies(df3q2, columns=['furnishingstatus'], drop_first=True)
df3q2 = df3q2.replace({
    False:0,True:1,
})
# Out:
# C:\Users\Sainath\AppData\Local\Temp\ipykernel_19996\360178246.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df3q2 = df3q2.replace({

# %%
x_train_3b, x_test_3b, y_train_3b, y_test_3b = tts(df3q2.iloc[:, 1:], df3q2.iloc[:, 0], test_size=0.2, random_state=42)

# %%
model5 = LR().fit(x_train_3b, y_train_3b)
y_pred5 = model5.predict(x_test_3b)

# %% [markdown]
# <h3>Q4<br> a. Classify the Iris flower dataset using Support Vector Machine (SVM) and identify the
# flower type based on given input data.<br>
# b. Predict whether breast cancer is benign or malignant using the K-Nearest Neighbors
# (KNN) Classifier for a given dataset</h3>

# %%
from sklearn.svm import SVC
from sklearn.datasets import *
iris = load_iris()
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df['species'] = iris.target
iris_df['species'] = iris_df['species'].map({0: 'setosa', 1: 'versicolor', 2: 'virginica'})
x_train_4a, x_test_4a, y_train_4a, y_test_4a = tts(iris_df.iloc[:, :-1], iris_df.iloc[:, -1], test_size=0.2, random_state=42)

# %%
scaler = StandardScaler()
x_train_4a = scaler.fit_transform(x_train_4a)
x_test_4a = scaler.transform(x_test_4a)

# %%
svm_classifier = SVC(kernel='linear')
svm_classifier.fit(x_train_4a, y_train_4a)
# Out:
# SVC(kernel='linear')

# %%
y_pred6 = svm_classifier.predict(x_test_4a)
accuracy = accuracy_score(y_test_4a, y_pred6)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 96.67%

# %%
from sklearn.neighbors import KNeighborsClassifier
cancer_df = pd.read_csv("cancerdata.csv")
cancer_df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M    14.204716     20.202641          122.80     1001.0
# 1    842517         M    18.483496     22.464181          132.90     1326.0
# 2  84300903         M    15.516300     18.271486          130.00     1203.0
# 3  84348301         M    15.540583     27.560108           77.58      386.1
# 4  84358402         M    14.005198     11.678064          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0         0.096113          0.089479        0.184766             0.096526
# 1         0.094443          0.063299        0.086927             0.021108
# 2         0.075842          0.059376        0.132738             0.052357
# 3         0.091525          0.088022        0.194466             0.010895
# 4         0.092790          0.010642        0.030518             0.037828
#
# ...

# %%
cancer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
cancer_df = cancer_df.replace({
    'M':1,
    'B':0
})
cancer_df = cancer_df.iloc[:, 1:]

# %%
x_train_4b, x_test_4b, y_train_4b, y_test_4b = tts(cancer_df.iloc[:, 1:], cancer_df.iloc[:,0], test_size=0.2, random_state=42)

# %%
model6 = KNeighborsClassifier()
model6.fit(x_train_4b, y_train_4b)
# Out:
# KNeighborsClassifier()

# %%
y_pred7 = model6.predict(x_test_4b)

# %%
accuracy_score(y_test_4b, y_pred7)
# Out:
# 0.9473684210526315

# %% [markdown]
# <h3>Q4<br>a. Analyze weather data using Gaussian Naïve Bayes Classifier and predict whether
# cricket can be played under new conditions.<br>
# b. Train the Random Forest model on the scikit-learn digits dataset and check if the
# model correctly predicts handwritten digits.</h3>

# %% [markdown]
# <p>Refer to the above code for cricket data(Q2, b)</p>

# %%
# x_train_2b, x_test_2b, y_train_2b, y_test_2b
from sklearn.naive_bayes import GaussianNB
model7 = GaussianNB()
model7.fit(x_train_2b, y_train_2b)
# Out:
# GaussianNB()

# %%
y_pred8 = model7.predict(x_test_2b)

# %%
print(f"The accuracy of gauss naive bayes: {accuracy_score(y_test_2b, y_pred8)*100}%")
# Out:
# The accuracy of gauss naive bayes: 66.66666666666666%

# %%
digits = load_digits()
digits.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'feature_names', 'target_names', 'images', 'DESCR'])

# %%
digits['data'].shape, digits['images'].shape, digits['target'].shape
# Out:
# ((1797, 64), (1797, 8, 8), (1797,))

# %%
plt.figure(figsize=(2,2))
plt.imshow(digits['images'][6])
plt.grid()

# %%
x_train_5b, x_test_5b, y_train_5b, y_test_5b = tts(digits['data'], digits['target'], random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
model8 = RandomForestClassifier(n_estimators=100, random_state=42)
model8.fit(x_train_5b, y_train_5b)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred9 = model8.predict(x_test_5b)

# %%
print(f"accuracy socre: {accuracy_score(y_test_5b, y_pred9)}")
# Out:
# accuracy socre: 0.9711111111111111

# %% [markdown]
# <h3>Q6)<br>a. Use the K-Means clustering algorithm to classify employees into different income
# groups based on a given dataset.<br>
# b. Perform dimensionality reduction on the Iris flower dataset using PCA, reducing it to
# 1D, and train a model to predict the species of a new flower.
# </h3>

# %% [markdown]
# <p>a) dataset unavailable</p>

# %%
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
from sklearn.decomposition import PCA
scaler = StandardScaler()
X_scaled = scaler.fit_transform(iris_df.iloc[:, :-1])
pca = PCA(n_components=1)
X_pca = pca.fit_transform(X_scaled)

# %%
X_train_6b, X_test_6b, y_train_6b, y_test_6b = tts(X_pca, iris_df.iloc[:,-1], test_size=0.3, random_state=42)
model9 = RandomForestClassifier(n_estimators=100, random_state=42)
model9.fit(X_train_6b, y_train_6b)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred10 = model9.predict(X_test_6b)
print(f"accuracy = {accuracy_score(y_test_6b, y_pred10)*100}%")
# Out:
# accuracy = 93.33333333333333%

# %% [markdown]
# <h3>Q8-b Logistic Regression decision boundary</h3>

# %%
x_min, x_max, y_min,y_max = 0, df2q1['age'].max()+10, 0, 1
X,Y = np.meshgrid(np.linspace(x_min, x_max, 100), np.linspace(y_min, y_max, 100))
c = np.c_[X.ravel(), Y.ravel()]

# %%
plt.style.use("ggplot")
plt.plot(np.sort(c[:,0]), np.sort(model3.predict_proba(c[:,0].reshape(-1, 1))[:,1]),label="Proba for getting 1")
plt.axhline(0.5,c='b',label="Threshold = 0.5")
plt.scatter(df2q1['age'],df2q1.iloc[:,-1],c='g',label="Actual Output")
plt.xlabel("Age")
plt.ylabel("Probability")
plt.title("Logistic Regression")
plt.legend()
plt.show()
# Out:
# C:\Users\Sainath\anaconda3\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# <h3>Q10-a Look at pdf</h3>
